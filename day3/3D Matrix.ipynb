# %% [markdown]
# # 3D matrix

# %%
# !wget https://cdn.mos.cms.futurecdn.net/HjFE8NKWuCmgfHCcndJ3rK-1200-80.jpg
# Out:
# --2024-02-19 05:36:55--  https://cdn.mos.cms.futurecdn.net/HjFE8NKWuCmgfHCcndJ3rK-1200-80.jpg
# Resolving cdn.mos.cms.futurecdn.net (cdn.mos.cms.futurecdn.net)... 18.64.174.95, 18.64.174.35, 18.64.174.24, ...
# Connecting to cdn.mos.cms.futurecdn.net (cdn.mos.cms.futurecdn.net)|18.64.174.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117787 (115K) [image/jpeg]
# Saving to: ‘HjFE8NKWuCmgfHCcndJ3rK-1200-80.jpg’
#
# HjFE8NKWuCmgfHCcndJ 100%[===================>] 115.03K  --.-KB/s    in 0.04s
#
# 2024-02-19 05:36:55 (2.81 MB/s) - ‘HjFE8NKWuCmgfHCcndJ3rK-1200-80.jpg’ saved [117787/117787]

# %%
import cv2
img = cv2.imread("/content/HjFE8NKWuCmgfHCcndJ3rK-1200-80.jpg")

# %%
img
# Out:
# array([[[192, 164, 153],
#         [193, 165, 154],
#         [193, 165, 154],
#         ...,
#         [199, 173, 159],
#         [199, 173, 159],
#         [199, 173, 159]],
#
#        [[193, 165, 154],
#         [193, 165, 154],
#         [193, 165, 154],
#         ...,
#         [199, 173, 159],
#         [199, 173, 159],
#         [199, 173, 159]],
#
#        [[194, 166, 155],
#         [194, 166, 155],
#         [195, 167, 156],
#         ...,
#         [198, 172, 158],
#         [198, 172, 158],
#         [198, 172, 158]],
#
#        ...,
#
#        [[113, 165, 205],
#         [106, 158, 198],
#         [106, 158, 195],
#         ...,
#         [111, 164, 197],
#         [121, 171, 207],
#         [135, 185, 221]],
#
#        [[118, 170, 210],
#         [109, 161, 201],
#         [108, 160, 197],
#         ...,
#         [109, 162, 195],
#         [117, 167, 203],
#         [133, 183, 219]],
#
#        [[124, 176, 216],
#         [113, 165, 205],
#         [110, 162, 199],
# ...

# %%
img.ndim
# Out:
# 3

# %%
len(img)
# Out:
# 667
