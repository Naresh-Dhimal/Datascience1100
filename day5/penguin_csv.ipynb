# %%
# initializing panda
import pandas as pd

# %%
# to read csv file
df = pd.read_csv("penguins.csv")

# %%
# to print DataFrame
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# to previews first 5 rows(by default)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# to previews first 10 rows
df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# ...

# %%
# to preview last 5 rows(by default)
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
# to previews last 2 rows
df.tail(2)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
# random 5 rows
df.sample(5)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 147     Adelie      Dream            36.6           18.4              184.0
# 220     Gentoo     Biscoe            46.1           13.2              211.0
# 176  Chinstrap      Dream            46.7           17.9              195.0
# 103     Adelie     Biscoe            37.8           20.0              190.0
# 73      Adelie  Torgersen            45.8           18.9              197.0
#
#      body_mass_g     sex
# 147       3475.0  FEMALE
# 220       4500.0  FEMALE
# 176       3300.0  FEMALE
# 103       4250.0    MALE
# 73        4150.0    MALE

# %%
# random 10 rows with fixed seed
df.sample(5, random_state=1)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
# 102  Adelie  Biscoe            37.7           16.0              183.0
# 289  Gentoo  Biscoe            50.7           15.0              223.0
#
#      body_mass_g     sex
# 306       4600.0  FEMALE
# 341       5750.0    MALE
# 291       5000.0    MALE
# 102       3075.0  FEMALE
# 289       5550.0    MALE

# %%
# to know the(no_of_row, no_of_column)
df.shape
# Out:
# (344, 7)

# %% [markdown]
# # Data profiling and inspection

# %%
df.columns # to see the name of columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# to previews data of first 2 rows
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
# to describes numericla data
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# to check the data type
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
# to includes  object in describes
df.describe(include='object')
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %% [markdown]
# # Species Column
# * 344 rows
# * 3 unique categories
# * among 3 unique categories most occuring is Adelie
# * with 152 frequency

# %% [markdown]
# # Island Column
# * 344 rows
# * 3 unique categories
# * among 3 unique categories most occuring is Biscoe
# * with 168 frequency

# %% [markdown]
# # Sex Column
# * 344 rows
# * 2 unique categories
# * among 2 unique categories most occuring is Male
# * with 168 frequency

# %%
# to previews unique data in species column
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# to count unique data in species column
df['species'].nunique()
# Out:
# 3

# %%
# to value count of unique data in species
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# to previews unique data in island column
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
# to count unique data in species column
df['island'].nunique()
# Out:
# 3

# %%
# to value count of unique data in species
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# to previews unique data in sex column
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
# to count unique data in sex column
df['sex'].nunique()
# Out:
# 2

# %%
# to value count of unique data in species
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
# to prints information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# to check if data present null or not
df.isna()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
# to count null presnt in data
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# ` In Species and island no missing data`<br>
# ` But, in bill_length, bill_depth, flipper_length and body_mass has same number missing data 2`<br>
# ` In sex column there is 11 missing data`<br>

# %%
# loc to slice DataFrame
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# slice DataFrame according to island with value = "Torgerson"
df['island'] == 'Torgersen'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
df.loc[df['island'] == 'Torgersen']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
# to slice DataFrame according to island with value = "Biscoe"

df.loc[df['island']== 'Biscoe']
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 20        3400.0  FEMALE
# 21        3600.0    MALE
# 22        3800.0  FEMALE
# ...

# %%
# to slice DataFrame according to island with value = "Dream"
df[df['island']=='Dream']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 30        3250.0  FEMALE
# 31        3900.0    MALE
# ...

# %%
# to find mean flipper_length whose species is Adelie
df[df['species']=='Adelie']['flipper_length_mm'].mean()
# Out:
# 189.95364238410596

# %%
# to find mean bill_length_mm whose species in Chinstrap
df[df['species']=='Chinstrap']['bill_length_mm'].mean()
# Out:
# 48.83382352941177

# %%
df[(df['sex']== 'MALE') & (df['species']== 'Chinstrap')].bill_length_mm.mean()
# Out:
# 51.09411764705882

# %%
# to groupby to find bill_length_mm with species and sex
df.groupby(['species','sex']).bill_length_mm.mean()
# Out:
# species    sex
# Adelie     FEMALE    37.257534
#            MALE      40.390411
# Chinstrap  FEMALE    46.573529
#            MALE      51.094118
# Gentoo     FEMALE    45.563793
#            MALE      49.473770
# Name: bill_length_mm, dtype: float64

# %%
df.groupby(['species','sex','island']).mean()
# Out:
#                             bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   sex    island
# Adelie    FEMALE Biscoe          37.359091      17.704545         187.181818
#                  Dream           36.911111      17.618519         187.851852
#                  Torgersen       37.554167      17.550000         188.291667
#           MALE   Biscoe          40.590909      19.036364         190.409091
#                  Dream           40.071429      18.839286         191.928571
#                  Torgersen       40.586957      19.391304         194.913043
# Chinstrap FEMALE Dream           46.573529      17.588235         191.735294
#           MALE   Dream           51.094118      19.252941         199.911765
# Gentoo    FEMALE Biscoe          45.563793      14.237931         212.706897
#           MALE   Biscoe          49.473770      15.718033         221.540984
#
#                             body_mass_g
# species   sex    island
# ...

# %% [markdown]
# # slice rows and column using

# %% [markdown]
# ` Q. rows from 4, 10 and all column`

# %%
df.loc[4:10, :]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
#
#     body_mass_g     sex
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# 6        3625.0  FEMALE
# 7        4675.0    MALE
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN

# %%
# rows from 4, 10 and island from sex
df.loc[4:10, 'island':'sex']
# Out:
#        island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 4   Torgersen            36.7           19.3              193.0       3450.0
# 5   Torgersen            39.3           20.6              190.0       3650.0
# 6   Torgersen            38.9           17.8              181.0       3625.0
# 7   Torgersen            39.2           19.6              195.0       4675.0
# 8   Torgersen            34.1           18.1              193.0       3475.0
# 9   Torgersen            42.0           20.2              190.0       4250.0
# 10  Torgersen            37.8           17.1              186.0       3300.0
#
#        sex
# 4   FEMALE
# 5     MALE
# 6   FEMALE
# 7     MALE
# 8      NaN
# 9      NaN
# 10     NaN

# %%
# to find mean of body_mass_g whose island value = 'Dream', species value= 'Adelie' and sex = 'FEMALE'
df[(df['island']== 'Dream') & (df['species']=='Adelie') & (df['sex']=='FEMALE')].body_mass_g.mean()
# Out:
# 3344.4444444444443

# %% [markdown]
# # Slicing using iloc

# %% [markdown]
# ` Q. slice 14 to 19 rows and 1 to 4 columns`

# %%
df.iloc[14:20, 1:5]
# Out:
#        island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 14  Torgersen            34.6           21.1              198.0
# 15  Torgersen            36.6           17.8              185.0
# 16  Torgersen            38.7           19.0              195.0
# 17  Torgersen            42.5           20.7              197.0
# 18  Torgersen            34.4           18.4              184.0
# 19  Torgersen            46.0           21.5              194.0
