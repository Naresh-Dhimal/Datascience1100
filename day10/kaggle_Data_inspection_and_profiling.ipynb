# %%
# initializing pandas
import pandas as pd

# %%
# to read data.csv
df = pd.read_csv("data.csv")

# %%
# to display data of csv file
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.describe() # to reprsent numerical data in single data
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.describe(include="object") # to represent categorical data in single data
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4787            1110         4764          3048

# %%
df.head() # to reviews 5 first rows data by default
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.head(10) # to reviews first 10 rows data
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
df.tail() # to reviews last 5 rows data by default
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.tail(3) # to reviews last 3 rows data
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# ...

# %%
df.sample(5) # to reviews any 5 random data
# Out:
#              Make            Model  Year                Engine Fuel Type  \
# 10507       Acura              TLX  2017  premium unleaded (recommended)
# 10899        Audi              TTS  2015     premium unleaded (required)
# 4956       Nissan         Frontier  2015                regular unleaded
# 7364   Mitsubishi  Outlander Sport  2016                regular unleaded
# 823          Saab              9-3  2009  premium unleaded (recommended)
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 10507      290.0               6.0         AUTOMATIC    all wheel drive
# 10899      265.0               4.0  AUTOMATED_MANUAL    all wheel drive
# 4956       261.0               6.0         AUTOMATIC   rear wheel drive
# 7364       168.0               4.0         AUTOMATIC   four wheel drive
# 823        280.0               6.0         AUTOMATIC  front wheel drive
#
#        Number of Doors                   Market Category Vehicle Size  \
# ...

# %%
df.sample(12, random_state=0) # random 12 rows with fixed seed
# Out:
#                 Make          Model  Year                Engine Fuel Type  \
# 10736           Ford  Transit Wagon  2017                regular unleaded
# 3828      Oldsmobile   Eighty-Eight  1999                regular unleaded
# 4554            Ford          F-150  2017        flex-fuel (unleaded/E85)
# 2506           Dodge        Charger  2017  premium unleaded (recommended)
# 6745           Mazda   Mazdaspeed 6  2006     premium unleaded (required)
# 2263             GMC         Canyon  2012                regular unleaded
# 1121            Audi             A7  2015     premium unleaded (required)
# 8586          Nissan          Rogue  2017                regular unleaded
# 10575      Chevrolet        Tracker  2002                regular unleaded
# 5291   Mercedes-Benz       GL-Class  2015     premium unleaded (required)
# 396            Mazda              3  2016                regular unleaded
# 7054          Nissan         Murano  2017                regular unleaded
#
# ...

# %%
# .shape method to find number of rows and number of columns
df.shape
# Out:
# (11914, 16)

# %%
# here in this data there are 11914 rows and there is 16 columns

# %%
# to find number of dimension
df.ndim
# Out:
# 2

# %%
# here number of dimension in this data is "2"

# %%
# to finds the columns name
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.count("columns") # to see total number of columns
# Out:
# 0        16
# 1        16
# 2        16
# 3        16
# 4        16
#          ..
# 11909    16
# 11910    16
# 11911    16
# 11912    16
# 11913    16
# Length: 11914, dtype: int64

# %%
df.dtypes # to see datatypes of data in this csv file
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.describe(include='object')
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4787            1110         4764          3048

# %%
# to see the unique() data of make
df["Make"].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
# to see value count in 'Make'
df["Make"].value_counts()
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
# to see the unique() data of Transmission Type
df["Transmission Type"].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
df['Transmission Type'].nunique() # to see total number of unique data of 'Transmission Type'
# Out:
# 5

# %%
df['Transmission Type'].value_counts()  # to see value count in 'Transmission Type'
# Out:
# Transmission Type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
# to prints information about the DataFrame
df.info
# Out:
# <bound method DataFrame.info of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# to check if data present null or not
df.isna()
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %%
# to count null presnt in data or not
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# Here, highest number of data is missing that is 3742 in Market Category

# %%
# indexing 
df["Vehicle Style"]
# Out:
# 0                Coupe
# 1          Convertible
# 2                Coupe
# 3                Coupe
# 4          Convertible
#              ...
# 11909    4dr Hatchback
# 11910    4dr Hatchback
# 11911    4dr Hatchback
# 11912    4dr Hatchback
# 11913            Sedan
# Name: Vehicle Style, Length: 11914, dtype: object

# %%
df["Popularity"]
# Out:
# 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916
#          ...
# 11909     204
# 11910     204
# 11911     204
# 11912     204
# 11913      61
# Name: Popularity, Length: 11914, dtype: int64

# %%
# Slicing
df["Vehicle Style"] == "Coupe"
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Name: Vehicle Style, Length: 11914, dtype: bool

# %%
df.loc[df["Make"] == "BMW"] # to slice BMW data
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
df.loc[df["Vehicle Style"] == "Coupe"] # to slice Vehice Style == Coupe
# Out:
#          Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0         BMW  1 Series M  2011  premium unleaded (required)      335.0
# 2         BMW    1 Series  2011  premium unleaded (required)      300.0
# 3         BMW    1 Series  2011  premium unleaded (required)      230.0
# 5         BMW    1 Series  2012  premium unleaded (required)      230.0
# 7         BMW    1 Series  2012  premium unleaded (required)      300.0
# ...       ...         ...   ...                          ...        ...
# 11792  Subaru          XT  1991             regular unleaded       97.0
# 11793  Subaru          XT  1991             regular unleaded      145.0
# 11794  Subaru          XT  1991             regular unleaded      145.0
# 11890     BMW        Z4 M  2007  premium unleaded (required)      330.0
# 11892     BMW        Z4 M  2008  premium unleaded (required)      330.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df[df["Make"]=="Subaru"]
# Out:
#          Make         Model  Year             Engine Fuel Type  Engine HP  \
# 1747   Subaru    B9 Tribeca  2006  premium unleaded (required)      250.0
# 1748   Subaru    B9 Tribeca  2006  premium unleaded (required)      250.0
# 1749   Subaru    B9 Tribeca  2006  premium unleaded (required)      250.0
# 1750   Subaru    B9 Tribeca  2006  premium unleaded (required)      250.0
# 1751   Subaru    B9 Tribeca  2006  premium unleaded (required)      250.0
# ...       ...           ...   ...                          ...        ...
# 11804  Subaru  XV Crosstrek  2015             regular unleaded      160.0
# 11805  Subaru  XV Crosstrek  2015             regular unleaded      160.0
# 11806  Subaru  XV Crosstrek  2015             regular unleaded      148.0
# 11807  Subaru  XV Crosstrek  2015             regular unleaded      148.0
# 11808  Subaru  XV Crosstrek  2015             regular unleaded      148.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# ...

# %%
# to find mean of Engine Hp of Make 'BMW'
round(df[df["Make"]=="BMW"]["Engine HP"].mean(), 2)
# Out:
# 326.91

# %%
# here, mean of engine hp of BMW is 326.91

# %%
# to find mean of engine cylinder of "Subaru" with "Transmission Type = AUTOMATIC"
round(df[(df['Make']== 'Subaru') & (df['Transmission Type']=='AUTOMATIC')]['Engine Cylinders'].mean(),2)
# Out:
# 4.62

# %%
# here, mean of engine cylinder of "Subaru" with "Transmission Type = AUTOMATIC" is  4.62

# %%
df.loc[1:3,:] # slicing rows 1 to 3 here, loc is used so location of data 1 to 3 is present and for column all is present
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1  BMW  1 Series  2011  premium unleaded (required)      300.0
# 2  BMW  1 Series  2011  premium unleaded (required)      300.0
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
#
#            Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1       Luxury,Performance      Compact   Convertible           28        19
# 2  Luxury,High-Performance      Compact         Coupe           28        20
# 3       Luxury,Performance      Compact         Coupe           28        18
#
#    Popularity   MSRP
# 1        3916  40650
# 2        3916  36350
# 3        3916  29450

# %%
# .loc[]
df.loc[1:4, 'Make':'Engine HP'] # slicing rows 1 to 4 here, loc is used so location of data 1 to 4 is present and for column from "Make": "Engine HP"
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP
# 1  BMW  1 Series  2011  premium unleaded (required)      300.0
# 2  BMW  1 Series  2011  premium unleaded (required)      300.0
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0

# %%
# .iloc[]
df.iloc[1:4, 1:4] # slicing rows 1 to 4 here, iloc is used so location of data 1 to 3 is present and for column from 1 to 3
# Out:
#       Model  Year             Engine Fuel Type
# 1  1 Series  2011  premium unleaded (required)
# 2  1 Series  2011  premium unleaded (required)
# 3  1 Series  2011  premium unleaded (required)

# %%
# .groupby[]
df.groupby((df['Make']=='BMW') & (df['Transmission Type']=="AUTOMATIC"))["Engine HP"].mean()
# Out:
# False    247.754098
# True     323.560784
# Name: Engine HP, dtype: float64

# %%
df[(df['Make']=='BMW') & (df['Transmission Type']=="AUTOMATIC")]["Engine HP"].isna().sum()
# Out:
# 0

# %%
round(df[(df['Make']=='BMW') & (df['Transmission Type']=="AUTOMATIC")]["Engine HP"].mean(), 2)
# Out:
# 323.56

# %%
df.groupby(['Make','Transmission Type','Vehicle Style'])['Engine HP'].mean()
# Out:
# Make   Transmission Type  Vehicle Style
# Acura  AUTOMATED_MANUAL   Coupe            573.000000
#                           Sedan            220.100000
#        AUTOMATIC          2dr Hatchback    153.750000
#                           4dr Hatchback    300.000000
#                           4dr SUV          279.709677
#                                               ...
# Volvo  AUTOMATIC          Sedan            230.441558
#                           Wagon            223.870588
#        MANUAL             2dr Hatchback    227.000000
#                           Sedan            164.173913
#                           Wagon            150.153846
# Name: Engine HP, Length: 486, dtype: float64

# %%
df.describe(include='object')
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4787            1110         4764          3048

# %%
df.groupby([	'Make',	'Model',	'Engine Fuel Type'	,"Transmission Type",	"Driven_Wheels", "Market Category",	"Vehicle Size",	"Vehicle Style"]).mean()
# Out:
#                                                                                                                                               Year  \
# Make  Model Engine Fuel Type               Transmission Type Driven_Wheels     Market Category                  Vehicle Size Vehicle Style
# Acura CL    premium unleaded (required)    AUTOMATIC         front wheel drive Factory Tuner,Luxury,Performance Midsize      Coupe          2003.0
#                                                                                Luxury                           Midsize      Coupe          2002.0
#                                            MANUAL            front wheel drive Factory Tuner,Luxury,Performance Midsize      Coupe          2003.0
#       ILX   premium unleaded (recommended) AUTOMATED_MANUAL  front wheel drive Luxury                           Compact      Sedan          2016.5
# ...
